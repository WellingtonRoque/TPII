# %% [markdown]
# <a href="https://colab.research.google.com/github/WellingtonRoque/TPII/blob/main/Atividades/atividade1_TP2_descricao.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Técnicas de Programação II
# ## 📌 Atividade 1 — Desenvolvimento de Sistema Web (Flask)
#
# ## 🎯 Objetivo da Atividade
#
# Nesta atividade você deverá desenvolver um sistema web utilizando os conceitos trabalhados até a **Aula 5**.
#
# ⚠️ Importante:
# Nesta etapa **NÃO será utilizado banco de dados (SQLAlchemy)**.
# Os dados podem ser armazenados em listas (memória).

# %% [markdown]
# ## 📚 Conteúdo Avaliado
#
# Esta atividade contempla:
#
# - Estrutura de projeto Flask
# - Rotas
# - Parâmetros
# - Templates (Jinja2)
# - Layout base (herança)
# - Interface com Bootstrap

# %% [markdown]
# ## 🛒 Contexto do Projeto
#
# Você deverá desenvolver um sistema web completo com interface amigável.
#
# 👉 **Sistema de Cadastro e Gerenciamento**
#
# O sistema deve permitir:
#
# - Cadastro de dados
# - Listagem de dados
# - Navegação entre páginas

# %% [markdown]
# ## 🧱 Estrutura Mínima do Projeto
#
# ```
# projeto/
# ├── app.py
# └── templates/
#     ├── base.html
#     ├── index.html
#     ├── cadastro.html
#     ├── lista.html
# ```

# %% [markdown]
# ## ⚙️ Requisitos Obrigatórios
#
# ### ✔ Interface
# - Utilizar Bootstrap
# - Layout base com herança
# - Navegação funcional
#
# ### ✔ Funcionalidades
# - Cadastro via formulário
# - Listagem dos dados
# - Organização visual
#
# ### ✔ Código
# - Uso correto de rotas
# - Uso de render_template

# %% [markdown]
# ## 🧠 Escolha do Tema
#
# Você pode escolher um dos cenários:
#
# ### 🔹 Cadastro de Usuário
# - Nome
# - E-mail
# - Senha
#
# Funcionalidades:
# - Validação
# - Evitar duplicidade
# - Listagem
#
# ---
#
# ### 🔹 Cadastro de Produtos
# - Nome
# - Preço
# - Categoria
#
# ---
#
# ### 🔹 Cadastro de Clientes
# - Nome
# - Telefone
# - Endereço
#
# ---
#
# ### 🔹 Sistema Livre
# Criar seu próprio sistema.

# %% [markdown]
# ## 🧪 Funcionalidades Esperadas
#
# Fluxo do sistema:
#
# 1. Acessar cadastro
# 2. Preencher formulário
# 3. Salvar dados
# 4. Visualizar na listagem

# %% [markdown]
# ## 🎨 Interface
#
# - Uso de Bootstrap
# - Botões e navegação
# - Organização visual

# %% [markdown]
# ## 📌 Critérios de Avaliação
#
# - Estrutura do projeto
# - Funcionamento
# - Uso de templates
# - Interface

# %% [markdown]
# ## 🚀 Entrega
#
# - Código fonte completo
# - Sistema funcionando
# - GitHub ou .zip

# %% [markdown]
# ## ⚠️ Observações
#
# - Não usar banco de dados
# - Não usar SQLAlchemy
#
# 👉 Próxima etapa: CRUD + Banco
